# %% [markdown]
# Import das bibliotecas

# %%
# Importe da biblioteca pandas

import pandas as pd

# %%
#Leitura dos dados

df = pd.read_csv('dados_agregados.csv')

# %% [markdown]
# Tratamento dos dados

# %%
# Tratamento de dados excluindo colunas NaN que não tem impacto nos dados

df = df.dropna(axis=1)

# %%
df
# Out:
#       Numero                    Nome             Tipe  Total   HP  Ataque  \
# 0          1               Bulbasaur     Grass Poison    318   45      49
# 1          2                 Ivysaur     Grass Poison    405   60      62
# 2          3                Venusaur     Grass Poison    525   80      82
# 3          3  Venusaur Mega Venusaur     Grass Poison    625   80     100
# 4          4              Charmander             Fire    309   39      52
# ...      ...                     ...              ...    ...  ...     ...
# 1190    1006            Iron Valiant   Fairy Fighting    590   74     130
# 1191    1007                Koraidon  Fighting Dragon    670  100     135
# 1192    1008                Miraidon  Electric Dragon    670  100      85
# 1193    1009            Walking Wake     Water Dragon    590   99      83
# 1194    1010             Iron Leaves    Grass Psychic    590   90     130
#
#       Defesa  Velocidade  Velocidade de ataque  Velocidade de defesa
# ...
